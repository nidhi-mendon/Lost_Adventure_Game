# %% [markdown]
# INTRODUCTION:
#
# Lost is an American science fiction drama television series that contains elements of supernatural fiction, and follows the survivors of a commercial jet airliner flying between Sydney and Los Angeles after the plane crashes on a mysterious island somewhere in the South Pacific Ocean. The show begins with the aftermath of a plane crash, which leaves the surviving passengers of Oceanic Airlines Flight 815 on what seems to be an uninhabited tropical island. Their survival is threatened by a number of mysterious entities, including polar bears, an unseen creature that roams the jungle (the "Smoke Monster"), and the island's malevolent inhabitants known as "The Others".

# %%
##A2: Text Adventure Game Development
##Name: Nidhi Mendon
##Professor: Chase Kusterer
##Course: Python for Data Analysts: Methods & Tools - DAT-7466 - FMBANDD
##Program: MBAN - Dual Degree




def lost_adventure_game():
    
        # Introduction to the 'Lost' game
    player_name = input("\nWhat's your name? \n") 
    print("\n٭⊹¤.•⨳•.*☆✬ 🌲🌳🛩️🏝️🌴 𝕎𝔼𝕃ℂ𝕆𝕄𝔼 𝕋𝕆 𝕋ℍ𝔼 𝕃𝕆𝕊𝕋 𝔸𝔻𝕍𝔼ℕ𝕋𝕌ℝ𝔼 𝔾𝔸𝕄𝔼 🌲🌳🛩️🏝️🌴 ✬☆*.•⨳•.¤⊹٭")
    print(f"\nHi {player_name.capitalize()}, you are one of the 48 survivors of Oceanic Flight 815 from Sydney to Los Angeles\nthat crashed on a lush, mysterious island in the South Pacific...")
    
    print("You'll need to make certain choices to survive on this island...\n")
    answer = input(prompt = 'Are you ready to play the game ? (yes/no): \n')
    
    # Select yes/no if you want to play the game
    if answer.lower() == 'yes' or answer.lower() == 'y':
        print("\nLet's get started!\n")
    # LEVEL 1: Initial location on the island
        location = "Jungle"
    # Game loop
        while location != "end":
            if location == "Jungle":
                # Player has the option to go to the cockpit of the plane or near the other survivors
                input(prompt = "Press any key to continue.")
                print("\nLEVEL 1...\n")
                print("After the flight hits turbulence and crashes on a mysterious island, you gain consciousness\nin the middle of a jungle on the island...\n")
                print("You see the crashed plane on one side of the jungle and hear ocean waves and screams\nof the survivors on the other side of the jungle. Do you want to get the transceiver from the\ncockpit of the plane to send a distressed signal or help out the other survivors from the plane crash?")
                choice = input("\nEnter 1 for 'plane' or 2 for 'survivors': ") # Which option do you want to choose?
                if choice.lower() == "1":
                    location = "Plane"
                elif choice.lower() == "2":
                    location = "Survivors"
                
            elif location == "Plane":
            # Level 1A: Player has to solve a riddle to get the transceiver
                print("\nYou have entered the cockpit of the plane and you look around to find a trasceiver...") # What you see in the cockpit of the plane
                print("\nHowever you realize there is a small vault in the corner with the transceiver in it. There's a riddle on\ntop of the vault, the answer to which is the password to the vault. You have to solve it to get the transceiver.")
                riddle = "What kind of tree can you carry in your hand? HINT: 4 letter word: P _ _ M ✋🏼"
                print(riddle)
                answer = input("What's the answer? ") # Enter the answer
                if answer.lower() == "palm":
                    print("\nCongratulations! You got the transceiver.")
                    print("LEVEL 1: SUCCESSFUL\n")
                    print("------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
                    location = "Cave"
                else:
                    print("\nWrong! The vault is locked.") # For wrong answers
                    print("LEVEL 1: FAILED")
                    location = "end"
                    fail()
                    exit()
                
            elif location == "Survivors":
            # Level 1B: Player has to solve a riddle to unlock the trunk for food
                print("\nYou are by a ocean where you see all the survivors of the plane crash along with their belongings\nscattered by the shore...")
                print("They look scared, injured and disoriented. If they all eat something, they will feel better and be more\nproactive to find a solution to their situation.")
                print("You find a trunk along with the belongings of the survivors which has food in it. But there's a riddle\nwritten on it, the answer to which is the password to the trunk. You have to solve it to get the food\nfor all survivors...")
                riddle = "I am easy to lift, but hard to throw. What am I? HINT: 7 letter word: F _ _  T _ _ R 🪶"
                print(riddle)
                answer = input("What's the answer? ")
                if answer.lower() == "feather":
                    print("\nCongratulations! You got the food for the survivors.")
                    print("LEVEL 1: SUCCESSFUL\n")
                    print("------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
                    location = "Cave"
                else:
                    print("\nWrong! The survivors are starving.")
                    print("LEVEL 1: FAILED")
                    location = "end"
                    fail()
                    exit()
                    
            elif location == "Cave":
            # Level 2: Player has to solve a riddle to inhabit other survivors in the cave
                print("\n\n\nLEVEL 2...\n")
                print("You are outside a cave which looks safe and habitable to live in...")
                print("You have to solve a riddle to enter the cave with the other survivors...")
                riddle = "Pronounced as 1 letter, And written with 3, 2 letters there are, and 2 only in me. I’m double, I’m single,\nI’m black blue, and gray, I’m read from both ends, and the same either way. What am I? HINT: 3 letter word: _ Y _ 👁️"
                print(riddle)
                answer = input("What's the answer? ")
                answer = str(answer)
                if answer.lower() == "eye":
                    print("\nCongratulations! You have a new home.")
                    print("LEVEL 2: SUCCESSFUL\n")
                    print("------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
                    location = "Jungle_1"
                else:
                    print("\nWrong! The cave has collapsed.")
                    print("LEVEL 2: FAILED")
                    location = "end"
                    fail()
                    exit()
                    
            elif location == "Jungle_1":
            # Level 3: Player has to choose a weapon to protect the child
                weapons = ["drop nets, gun, pocket knife"]
                print("\n\n\nLEVEL 3...\n")
                print("You are running out of food for survival. So you and the other survivors decide to go hunting for food...")
                for x in weapons:
                    print(f"You have some weapons to trap an animal: {x}")
                print("Suddenly, you see a wild boar about to attack a 10-year old kid. You have to act fast...")
                riddle = "Which weapon would you use? '1' for nets, '2' for guns, '3' for knife"
                print(riddle)
                answer = input("What's the answer? ")
                if answer == "2":
                    print("\nCongratulations! You shot the boar and saved the child.")
                    print("LEVEL 3: SUCCESSFUL\n")
                    print("------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
                    location = "Raft"
                elif answer == "3":
                    print("\nCongratulations! You stabbed the boar and saved the child.")
                    print("LEVEL 3: SUCCESSFUL\n")
                    print("------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
                    location = "Raft"
                elif answer == "1":
                    print("\nCongratulations! You trapped the boar and saved the child.")
                    print("LEVEL 3: SUCCESSFUL\n")
                    print("------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
                    location = "Raft"
                else:
                    print("\nWrong! The boar attacked the child.")
                    print("LEVEL 3: FAILED")
                    location = "end"
                    fail()
                    exit()
            
            elif location == "Raft":
            # Level 4: Player has to solve a riddle to build a raft
                print("\n\n\nLEVEL 4...\n")
                print("You are walking through the jungle and you find a few logs of wood which are approximately 8-9 ft long.\nYou remember seeing bundles of ropes along with the belongings of other survivors...")
                print("You can build a raft to get off the island. You take the logs towards the shore and go look for the ropes\njust to realize that Sawyer, one of the survivors has the ropes. He gives you a riddle to solve in exchange\nfor the ropes...")
                riddle = "Paul's height is six feet, he's an assistant at a butcher's shop, and wears size 9 shoes. What does he weigh? HINT: 4 letter word: _ E _ T 🥩"
                print(riddle)
                answer = input("What's the answer? ")
                if answer.lower() == "meat":
                    print("\nCongratulations! You got the ropes to built a raft.")
                    print("LEVEL 4: SUCCESSFUL\n")
                    print("------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
                    location = "end"
                    win()
                    exit()
                else:
                    print("\nWrong! You can't build a raft.")
                    print("LEVEL 4: FAILED")
                    location = "end"
                    fail()
                    exit()
    #If the player decides not to play    
    else:
        print("I am sorry to see you go...")
        exit()

# Defining win
def win():
    print("Wohooo! Great survival skills! You got off the island and you have survived.")
    
# Defining fail
def fail():
    print("You lost the game.")

# Defining exit
def exit():
    print("END GAME.")

lost_adventure_game()
